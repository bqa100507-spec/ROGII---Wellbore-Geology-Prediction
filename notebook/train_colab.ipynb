# %% [markdown]
# # Train Autoregressive LightGBM on Colab
#
# If you open this notebook directly from GitHub via Colab, the environment will be empty.
# This notebook will mount Google Drive, clone the repository, extract the dataset, and run the training script.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os
if os.path.exists('/content'):
    os.chdir('/content')
# !rm -rf ROGII---Wellbore-Geology-Prediction

BRANCH = 'main'
# !git clone -b {BRANCH} https://github.com/bqa100507-spec/ROGII---Wellbore-Geology-Prediction.git
os.chdir('ROGII---Wellbore-Geology-Prediction')

# %%
# !mkdir -p data
# !unzip -qo /content/drive/MyDrive/ROGII/rogii-wellbore-geology-prediction.zip -d data

# %%
# !pip install -q -r requirements.txt

# %%
EXP_NAME = 'lgbm_baseline'

# %%
# !python src/train.py --data_dir data --exp_name {EXP_NAME} --split holdout --valid_size 0.2

# %%
# !zip -r {EXP_NAME}.zip model/{EXP_NAME}/
# Tùy chọn: Copy file zip lên Google Drive
# !cp {EXP_NAME}.zip /content/drive/MyDrive/ROGII/ 2>/dev/null || echo 'Đã nén xong ({EXP_NAME}.zip).'
