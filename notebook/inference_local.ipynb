# %% [markdown]
# # Local Recursive Inference

# %%
# !python ../src/predict.py --data_dir ../data --model_dir ../model/lgbm_baseline --output ../data/submission.csv
# Out:
# Saved submission to ../data/submission.csv
# Rows: 14151, NaN tvt: 0
# Predicting test wells:   0%|          | 0/3 [00:00<?, ?it/s]
# Predicting test wells:  33%|███▎      | 1/3 [00:51<01:43, 51.77s/it]
# Predicting test wells:  67%|██████▋   | 2/3 [01:42<00:51, 51.30s/it]
# Predicting test wells: 100%|██████████| 3/3 [02:19<00:00, 44.52s/it]
# Predicting test wells: 100%|██████████| 3/3 [02:19<00:00, 46.39s/it]

# %%
import pandas as pd
sub = pd.read_csv('../data/submission.csv')
sub.head(), sub.shape, sub['tvt'].isna().sum()
# Out:
# (              id           tvt
#  0  000d7d20_1442  11747.305062
#  1  000d7d20_1443  11747.324118
#  2  000d7d20_1444  11747.316547
#  3  000d7d20_1445  11747.326952
#  4  000d7d20_1446  11747.291513,
#  (14151, 2),
#  np.int64(0))
